# %% [markdown]
# <a href="https://colab.research.google.com/github/hiral1547/RoadShield-AI/blob/main/notebooks/Day01_RoadShieldAI_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Mount Google Drive
#Authorize Google Drive access.

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Verify the Folder

import os
project_path = "/content/drive/My Drive/RoadShield-AI"
print(os.listdir(project_path))
# Out:
# ['notebooks']

# %%
#Install Required Libraries
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 4.2 MB/s eta 0:00:00
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
import cv2
import numpy as np

print("OpenCV :", cv2.__version__)
print("NumPy :", np.__version__)
# Out:
# OpenCV : 4.13.0
# NumPy : 2.0.2

# %%
import cv2
image_path="/content/drive/My Drive/RoadShield-AI/assets/road.jpg"
image=cv2.imread(image_path)
print(image.shape)
# Out:
# (1004, 1500, 3)

# %%
#display the image
import matplotlib.pyplot as plt

image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,6))
plt.imshow(image_rgb)
plt.axis("off")
plt.title("Road Image")
plt.show()

# %%
#Display Image Properties
print("Height :",image.shape[0])

print("Width :",image.shape[1])

print("Channels :",image.shape[2])
# Out:
# Height : 1004
# Width : 1500
# Channels : 3

# %%
#save a copy
output_path="/content/drive/My Drive/RoadShield-AI/outputs/images/output.jpg"

cv2.imwrite(output_path,image)
# Out:
# True

# %%
#Verify
import os

os.path.exists(output_path)
# Out:
# True

# %% [markdown]
# # RoadShield AI
#
# ## Goal
#
# Detect potholes using a smartphone camera in real time.
#
# ### Input
#
# - Smartphone Camera
#
# ### Output
#
# - Detect potholes
# - Draw bounding boxes
# - Voice alert
# - Save GPS coordinates
#
# ### Technologies
#
# - Python
# - OpenCV
# - YOLO
# - Google Colab
# - GitHub
